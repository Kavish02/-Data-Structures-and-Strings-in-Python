# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavish02/-Data-Structures-and-Strings-in-Python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sea
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re
# !gdown 1zxpcvlD72dxFFbZIpWLxzbbLT-bqFFul
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zxpcvlD72dxFFbZIpWLxzbbLT-bqFFul
# To: /content/train.csv
# 100% 61.2k/61.2k [00:00<00:00, 47.8MB/s]

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sea.heatmap(df.isnull(),cmap = 'magma')
# Out:
# <Axes: >

# %%
#define a function that replace the cabin code with the deck character
def search_substring(big_string, substring_list):
    for substring in substring_list:
        if substring in big_string:
            return substring
        return substring_list[-1]

# %%
#replace passenger's name with his/her title (mr , Mrs, Miss,Master)
def get_title(string):
    regex = re.compile(r'Mr|Don|Major|Capt|Jonkheer|Rev|Col|Dr|Mrs|Countess|Dona|Mme|Ms|Miss|Master',re.IGNORECASE)
    results = regex.search(string)
    if results != None :
        return(results.group().lower())
    else:
        return(str(np.nan))

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
cabin_list =['A','B','C','D','E','F','T','G','Unknown']
print(cabin_list)
#print(sorted(cabin_list))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'T', 'G', 'Unknown']

# %%
text= "My name is kavish. "
match= re.search("kavish",text)
print(match.group())
# Out:
# kavish

# %%
# dictionary to map to generate the new feature vector
title_dictionary = {
"capt":"Officer",
"col":"Officer",
"major":"Officer",
"dr":"Officer",
"jonkheer":"Royalty",
"rev":"Officer",
"countess":"Royalty",
"dona":"Royalty",
"lady":"Royalty",
"don":"Royalty",
"mr":"Mr",
"mme":"Mrs",
"ms":"Mrs",
"mrs":"Mrs",
"miss":"Miss",
"mlle":"Miss",
"master":"Master",
"nan":"Mr"
}

# %%
df['deck']= df['Cabin'].map(lambda x : search_substring(str(x),cabin_list))

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df['Title'] = df['Name'].apply(get_title)

# %%
df['Title']= df['Title'].map(title_dictionary)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked     deck Title
# 0      0         A/5 21171   7.2500        S  Unknown    Mr
# 1      0          PC 17599  71.2833        C  Unknown    Mr
# 2      0  STON/O2. 3101282   7.9250        S  Unknown  Miss
# 3      0            113803  53.1000        S  Unknown    Mr
# ...

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Embarked     deck Title
# 0         A/5 21171   7.2500        S  Unknown    Mr
# 1          PC 17599  71.2833        C  Unknown    Mr
# 2  STON/O2. 3101282   7.9250        S  Unknown  Miss
# 3            113803  53.1000        S  Unknown    Mr
# 4            373450   8.0500        S  Unknown    Mr

# %%
df.drop('Ticket',axis=1,inplace=True)

# %%
mean_title = df.groupby('Title')['Age'].mean()
mk = df.groupby('Title')['Age'].mean().plot(kind='bar')

# %%
title_list = ['Mr', 'Miss', 'Mrs', 'Master', 'Royalty', 'Officer']
def age_nan_replace(means, dframe, title_list):
    for title in title_list:
        temp = dframe['Title'] == title
        dframe.loc[temp, 'Age'] = dframe.loc[temp, 'Age'].fillna(means[title])
age_nan_replace(mean_title, df, title_list)
# age_nan_replace(means_title, title_list)

# %%
df['Embarked'].fillna
# Out:
# <bound method NDFrame.fillna of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
df['Family Size']= df['Parch'] + df['SibSp']
df.drop('Parch',axis=1,inplace=True)
df.drop('SibSp',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare Embarked     deck  \
# 0            1         0       3    male  22.0   7.2500        S  Unknown
# 1            2         1       1  female  38.0  71.2833        C  Unknown
# 2            3         1       3  female  26.0   7.9250        S  Unknown
# 3            4         1       1  female  35.0  53.1000        S  Unknown
# 4            5         0       3    male  35.0   8.0500        S  Unknown
#
#   Title  Family Size
# 0    Mr            1
# 1    Mr            1
# 2  Miss            0
# 3    Mr            1
# 4    Mr            0
